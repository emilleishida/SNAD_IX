# %%
import numpy as np
from time import monotonic
from datetime import timedelta
import matplotlib.pyplot as plt

from coniferest.datasets import plasticc_gp

from coniferest.session import oracle
from coniferest.isoforest import IsolationForest
from coniferest.aadforest import AADForest
from coniferest.pineforest import PineForest
from functools import partial

# %%
data, metadata = plasticc_gp()
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
#n_spare_trees = 4000
n_trees = 1000

models = {
    "Isolation Forest": partial(IsolationForest, n_trees=n_trees),
    "AAD Forest": partial(AADForest, n_trees=n_trees),
    "Pine Forest": partial(PineForest, n_trees=n_trees),
}

# %%
max_iterations = 100
max_trials = 5

steps = np.arange(1, max_iterations + 1)

anomalies = {}
wall_times = {}
for name, model_class in models.items():
    print(name, model_class)

    wall_time = []
    anomalies_ = []
    for i in range(max_trials):
        session = oracle.create_oracle_session(data, metadata,
                                                   model = model_class(random_seed = i, n_jobs=30),
                                                   max_iterations = max_iterations)

        start_time = monotonic()

        session.run()

        wall_time.append(timedelta(seconds = monotonic() - start_time))

        labels = (1 - np.asarray(list(session.known_labels.values()), dtype=int)) // 2
        anomalies_.append(np.cumsum(labels) / steps)

    anomalies[name] = np.asarray(anomalies_)
    wall_times[name] = np.median(np.asarray(wall_time))
# Out:
# Isolation Forest functools.partial(<class 'coniferest.isoforest.IsolationForest'>, n_trees=1000)
# AAD Forest functools.partial(<class 'coniferest.aadforest.AADForest'>, n_trees=1000)
# Pine Forest functools.partial(<class 'coniferest.pineforest.PineForest'>, n_trees=1000)

# %%
for name in models.keys():
    q5 = np.quantile(anomalies[name], 0.05, axis = 0)
    median = np.median(anomalies[name], axis = 0)
    q95 = np.quantile(anomalies[name], 0.95, axis = 0)

    plt.plot(steps, median,
             alpha=0.75,
             label="{} ({:.0f} sec.)".format(name, wall_times[name].total_seconds()))
    plt.fill_between(steps, q5, q95, alpha=0.5)

plt.legend()
plt.xlabel("Iteration")
plt.ylabel("Fraction of anomalies")
plt.title('PLAsTiCC')
plt.savefig('plots/PLAsTiCC_' + str (max_trials) + 'trials_' + str(n_trees) +'trees.png')
